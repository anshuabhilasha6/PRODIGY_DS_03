# %%
#importing the necessary libaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#reading the dataset
df=pd.read_csv("bank-additional-full.csv",delimiter=";")

# %%
#reading the first five rows
df.head(5)
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
#renaming the column y to the name subscribed
df.rename(columns={'y':'subscribed_deposit'},inplace=True)

# %%
#DETAILS ABOUT THE DATASET

# %%
#getting the information about the no.of rows and columns
df.shape
# Out:
# (41188, 21)

# %%
#getting the information about the columns
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'subscribed_deposit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 41188 non-null  int64
#  1   job                 41188 non-null  object
#  2   marital             41188 non-null  object
#  3   education           41188 non-null  object
#  4   default             41188 non-null  object
#  5   housing             41188 non-null  object
#  6   loan                41188 non-null  object
#  7   contact             41188 non-null  object
#  8   month               41188 non-null  object
#  9   day_of_week         41188 non-null  object
#  10  duration            41188 non-null  int64
#  11  campaign            41188 non-null  int64
#  12  pdays               41188 non-null  int64
#  13  previous            41188 non-null  int64
#  14  poutcome            41188 non-null  object
# ...

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
#checking for null value in the dataset
df.isnull().sum()
# Out:
# age                   0
# job                   0
# marital               0
# education             0
# default               0
# housing               0
# loan                  0
# contact               0
# month                 0
# day_of_week           0
# duration              0
# campaign              0
# pdays                 0
# previous              0
# poutcome              0
# emp.var.rate          0
# cons.price.idx        0
# cons.conf.idx         0
# euribor3m             0
# nr.employed           0
# subscribed_deposit    0
# dtype: int64

# %%
#HENCE NO MISSING/NULL VALUES PRESENT
#checking for duplicates values in the dataset
df.duplicated().sum()
# Out:
# 12

# %%
#removing all duplicates using the drop_dupliactes
df.drop_duplicates(inplace=True)

# %%
#AGAIN CHECKING FOR DUPLICATES
df.duplicated().sum()
# Out:
# 0

# %%
#ALL DUPLICATES REMOVED

# %%
#Visualizing numerical data columns using histogram
df_obj=df.select_dtypes(include='object').columns
df_num=df.select_dtypes(exclude='object').columns

# %%
for feature in df_num:
    sns.histplot(x=feature,data=df,bins=25,kde=True,color='#5f366e')
    plt.show()

# %%
# Display all columns in the DataFrame
print("Columns in DataFrame:", df.columns)

# Display data types of all columns
print("Data types of each column:\n", df.dtypes)

# Check if specific columns are present
print("emp.var.rate in DataFrame:", 'emp.var.rate' in df.columns)
print("cons.price.idx in DataFrame:", 'cons.price.idx' in df.columns)
print("cons.conf.idx in DataFrame:", 'cons.conf.idx' in df.columns)
# Out:
# Columns in DataFrame: Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'subscribed_deposit'],
#       dtype='object')
# Data types of each column:
#  age                     int64
# job                    object
# marital                object
# education              object
# default                object
# housing                object
# loan                   object
# contact                object
# month                  object
# day_of_week            object
# duration                int64
# campaign                int64
# pdays                   int64
# previous                int64
# poutcome               object
# emp.var.rate          float64
# cons.price.idx        float64
# cons.conf.idx         float64
# euribor3m             float64
# ...

# %%
#visualizing the categorical columns using bar graphs
for feature in df_obj:
    plt.figure(figsize=(6,3))
    plt.title(f"Count plot of {feature}")
    sns.countplot(x=feature,data=df,palette='viridis')
    plt.xticks(rotation=40)
    plt.show()

# %%
#OBSERVATION
## In job column, most of the clients are working as admin
##In martial column,most of the clients are married.
##In education column,most of the clients are having 'university.degree' as education.
##In default column,most of the clients are having no credit.
##In housing column,most of the clients are taking housing loan.
##In loan column,most of the clients are not taking personal loan.
##In contact column,most of the clients are using cellular contact.
##In month column, most clients are contacted in the month of 'MAY'.
##In day_of_week column,most clients are contacted on 'thursday'.
##In the poutcome column, we have seen results of the most of the previous market campaign is 'non-existent.
##In the target column,we have seen most of the clients are not subscribed a team deposit.

# %%
#CHECKING FOR OUTLIERS
df.plot(kind='box', subplots=True, layout=(5,2), figsize=(10,30))
plt.show()

# %%
#outlier treatment
columns=['age','campaign','duration']

for column in columns:
    q1=np.percentile(df[column],25)
    q3=np.percentile(df[column],75)
    iqr=q3-q1
    lower_bound=q1-(1.5*iqr)
    upper_bound=q3+(1.5*iqr)
    #filter the dataframe for the current column
    df=df[(df[column]>=lower_bound)&(df[column]<=upper_bound)]

# %%
df.plot(kind='box',subplots=True,layout=(5,2),figsize=(10,30))
plt.show()

# %%
#checking for correlation using heatmap
#select only the numerical columns
numerical_df = df.select_dtypes(include=[np.number])

#calculate the correlation matrix
correlation_matrix = numerical_df.corr()
#create a heatmap of the correlation matrix
plt.figure(figsize=(10,8))
sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm',vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
high_corr_cols = ['emp.var.rate','euribor3m','nr.employed']

# %%
#copying the original dataframe
df1=df.copy()
#removing highly correlated columns from the dataset
df1.drop(high_corr_cols,inplace=True,axis=1)
df1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'cons.price.idx', 'cons.conf.idx',
#        'subscribed_deposit'],
#       dtype='object')

# %%
#showing the dimension of updated sheet
df1.shape
# Out:
# (35550, 18)

# %%
#conversion of categorical columns into numerical columns using label encoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_encoded = df1.apply(le.fit_transform)
df_encoded
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0       39    3        1          0        0        0     0        1      6
# 1       40    7        1          3        1        0     0        1      6
# 2       20    7        1          3        0        2     0        1      6
# 3       23    0        1          1        0        0     0        1      6
# 4       39    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41181   20    0        1          6        0        2     0        0      7
# 41182   12   10        2          0        0        2     0        0      7
# 41184   29    1        1          5        0        0     0        0      7
# 41185   39    5        1          6        0        2     0        0      7
# 41186   27    9        1          5        0        0     0        0      7
#
# ...

# %%
#checking the target variable
df_encoded['subscribed_deposit'].value_counts(normalize=True)*100
# Out:
# subscribed_deposit
# 0    91.887482
# 1     8.112518
# Name: proportion, dtype: float64

# %%
#independent variable
x=df_encoded.iloc[:,:-1]
#target variable
y=df_encoded.iloc[:,-1]

# %%
x.shape
# Out:
# (35550, 17)

# %%
y.shape
# Out:
# (35550,)

# %%
#splitting the data into train and test datasets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (24885, 17)
# (10665, 17)
# (24885,)
# (10665,)

# %%
#decision tree classifier
from sklearn.tree import DecisionTreeClassifier
dc = DecisionTreeClassifier(criterion='gini',max_depth=5,min_samples_split=10)
dc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=10)

# %% [markdown]
# **EVALUATING TRAINING AND TESTING

# %%
print('Training Accuracy:',dc.score(x_train,y_train))
print('Testing Accuracy:',dc.score(x_test,y_test))
# Out:
# Training Accuracy: 0.9369901547116737
# Testing Accuracy: 0.93314580403188

# %%
y_pred=dc.predict(x_test)

# %%
#evaluating prediction accuracy
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print(accuracy_score(y_test,y_pred))
# Out:
# 0.93314580403188

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[9599  214]
#  [ 499  353]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      9813
#            1       0.62      0.41      0.50       852
#
#     accuracy                           0.93     10665
#    macro avg       0.79      0.70      0.73     10665
# weighted avg       0.92      0.93      0.93     10665

# %%
#PLOT DECISION TREE
from sklearn.tree import plot_tree
feature_names=df.columns.tolist()

plt.figure(figsize=(40,20))
class_names=["class_0","class_1"]
plot_tree(dc, feature_names=feature_names, class_names=class_names, filled=True,fontsize=8)
plt.show()

# %%
#DECISION TREE CLASSIFIER
from sklearn.tree import DecisionTreeClassifier
dc1 = DecisionTreeClassifier(criterion='entropy',max_depth=5,min_samples_split=10)
dc1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=10)

# %%
#evaluating the training and testing accuracy
print('Training Accuracy:',dc1.score(x_train,y_train))
print('Testing Accuracy:',dc1.score(x_test,y_test))
# Out:
# Training Accuracy: 0.9359855334538879
# Testing Accuracy: 0.9316455696202531

# %%
y1_pred=dc1.predict(x_test)

# %%
#evaluating the prediction accuracy
print(accuracy_score(y_test,y1_pred))
# Out:
# 0.9316455696202531

# %%
print(confusion_matrix(y_test,y1_pred))
# Out:
# [[9654  159]
#  [ 570  282]]

# %%
print(classification_report(y_test,y1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      9813
#            1       0.64      0.33      0.44       852
#
#     accuracy                           0.93     10665
#    macro avg       0.79      0.66      0.70     10665
# weighted avg       0.92      0.93      0.92     10665

# %%
cn=['no','yes']
fn=x_train.columns
plt.figure(figsize=(40,20))
plot_tree(dc1,feature_names=fn.tolist(),class_names=cn,filled=True,fontsize=10)
plt.show()
